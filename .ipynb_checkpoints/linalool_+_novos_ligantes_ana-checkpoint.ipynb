# %%
import numpy as np
import pickle
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
import sys
sys.path.append("../chembl_analyser/module/")
from calcula_tanimoto import *

# %%
from ddc_pub import ddc_v3 as ddc

# %%
import molvecgen

# %%
model_name = "models/pcb_model"
model = ddc.DDC(model_name=model_name)
# Out:
# Initializing model in test mode.
# Loading model.
# 'mol_to_latent_model' not found, setting to None.
# /home/alverad/anaconda3/envs/ddc_env/lib/python3.6/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator StandardScaler from version 0.20.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.
# Loading finished in 2 seconds.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Latent_Input (InputLayer)       [(None, 7)]          0
# __________________________________________________________________________________________________
# Decoder_Inputs (InputLayer)     [(None, 142, 35)]    0
# __________________________________________________________________________________________________
# latent_to_states_model (Model)  [(None, 256), (None, 18432       Latent_Input[0][0]
# __________________________________________________________________________________________________
# batch_model (Model)             (None, 142, 35)      1364771     Decoder_Inputs[0][0]
#                                                                  latent_to_states_model[1][0]
#                                                                  latent_to_states_model[1][1]
#                                                                  latent_to_states_model[1][2]
#                                                                  latent_to_states_model[1][3]
#                                                                  latent_to_states_model[1][4]
#                                                                  latent_to_states_model[1][5]
# ==================================================================================================
# Total params: 1,383,203
# Trainable params: 1,378,595
# Non-trainable params: 4,608
# __________________________________________________________________________________________________
# None

# %%
qsar_model_name = "models/qsar_model.pickle"
with open(qsar_model_name, "rb") as file:
    qsar_model = pickle.load(file)["classifier_sv"]
# Out:
# /home/alverad/anaconda3/envs/ddc_env/lib/python3.6/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator SVC from version 0.20.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
from rdkit import Chem, DataStructs
from rdkit.Chem import Descriptors, rdMolDescriptors, AllChem, QED
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
#We suppres stdout from invalid smiles and validations
from rdkit import rdBase
rdBase.DisableLog ( 'rdApp.*')

# %%
def get_descriptors(mol):
    logp  = Descriptors.MolLogP(mol)
    tpsa  = Descriptors.TPSA(mol)
    molwt = Descriptors.ExactMolWt(mol)
    hba   = rdMolDescriptors.CalcNumHBA(mol)
    hbd   = rdMolDescriptors.CalcNumHBD(mol)
    qed   = QED.qed(mol)
     
                     
    # Calculate fingerprints
    fp = AllChem.GetMorganFingerprintAsBitVect(mol,2, nBits=2048)
    ecfp4 = np.zeros((2048,))
    DataStructs.ConvertToNumpyArray(fp, ecfp4) 
    # Predict activity and pick only the second component
    active_probability = qsar_model.predict_proba([ecfp4])[0][1]
    return [logp, tpsa, molwt, qed, hba, hbd, active_probability]

# %%
smiles_target = "C=C[C@](C)(O)CCC=C(C)C"

# %%
mol = Chem.MolFromSmiles(smiles_target)
display(mol)
conditions = get_descriptors(mol)
conditions
# Out:
# [2.6698000000000013,
#  20.23,
#  154.135765196,
#  0.6171290071333284,
#  1,
#  1,
#  2.8304322844892562e-05]

# %%
target = np.array(conditions)
#smiles_out, _ = model.predict(latent=target, temp=1)
#Chem.MolFromSmiles(smiles_out)

# %%
#model.batch_input_length = 256
smiles_out = []
for i in range(100):
    smiles, _ = model.predict_batch(latent=target.reshape(1,-1), temp=1.0)
    smiles_out.append(smiles)
smiles_out = np.concatenate(smiles_out)
smiles_out.shape
# Out:
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# /home/alverad/notebook/Deep-Drug-Coder/ddc_pub/ddc_v3.py:1199: RuntimeWarning: divide by zero encountered in log
#   nextCharProbs = np.log(o) / temp
# (25600,)

# %%
mols = [Chem.MolFromSmiles(smi) for smi in smiles_out]

# %%
def sanitize(mol):
    try:
        Chem.SanitizeMol(mol)
        return mol
    except Exception as e:
        print(e)
         
sani_mols = [sanitize(mol) for mol in mols if mol != None]
# Out:
# Sanitization error: Explicit valence for atom # 10 O, 3, is greater than permitted
# Sanitization error: Explicit valence for atom # 9 O, 3, is greater than permitted

# %%
len(sani_mols)
# Out:
# 24354

# %%
len(sani_mols)/len(smiles_out)
# Out:
# 0.951328125

# %%
properties = [[Chem.MolToSmiles(mol)] + get_descriptors(mol) for mol in sani_mols if mol != None]
import pandas as pd
target_names = ["Smiles", "logp", "tpsa", "molwt", "qed", "hba", "hbd", "active_probability"]
data = pd.DataFrame(properties, columns=target_names)

# %%
data.sort_values(by='active_probability', ascending=False)
# Out:
#                     Smiles    logp     tpsa     molwt     qed  hba  hbd  \
# 19352    CC1CCc2ccc(O)cc21 2.44190 20.23000 148.08882 0.59877    1    1
# 8866     CC1CCc2ccc(O)cc21 2.44190 20.23000 148.08882 0.59877    1    1
# 12       CC1CCc2ccc(O)cc21 2.44190 20.23000 148.08882 0.59877    1    1
# 1535     CC1CCc2cc(O)ccc21 2.44190 20.23000 148.08882 0.59877    1    1
# 1071     CC1CCc2cc(O)ccc21 2.44190 20.23000 148.08882 0.59877    1    1
# ...                    ...     ...      ...       ...     ...  ...  ...
# 1468   CC(=O)Nc1cccc(C)c1C 2.26184 29.10000 163.09971 0.67561    1    1
# 12099  CC(=O)Nc1cc(C)ccc1C 2.26184 29.10000 163.09971 0.67561    1    1
# 7960      CC(=O)Nc1ccccc1C 1.95342 29.10000 149.08406 0.64929    1    1
# 7609      CC(=O)Nc1ccccc1C 1.95342 29.10000 149.08406 0.64929    1    1
# 3824     CCC(=O)Nc1ccccc1C 2.34352 29.10000 163.09971 0.71196    1    1
#
#        active_probability
# 19352             0.77673
# 8866              0.77673
# 12                0.77673
# 1535              0.69450
# 1071              0.69450
# ...                   ...
# 1468              0.00000
# 12099             0.00000
# 7960              0.00000
# 7609              0.00000
# 3824              0.00000
#
# [24352 rows x 8 columns]

# %%
len(data.loc[data.Smiles.str.contains('#')].sort_values(by='active_probability', ascending=False))
# Out:
# 41

# %%
data.loc[data.Smiles.str.contains('#')].sort_values(by='active_probability', ascending=False)
# Out:
#                             Smiles    logp     tpsa     molwt     qed  hba  \
# 19481            CCCC#Cc1ccc(O)cc1 2.54380 20.23000 160.08882 0.62579    1
# 17108    [C-]#[N+]c1ccc(C(N)=S)cc1 1.87159 30.38000 162.02517 0.50445    1
# 1793         C#CC(C)(C)C1CCC(=N)C1 2.46567 23.85000 149.12045 0.55370    1
# 2620               CCCC#Cc1ccccc1O 2.54380 20.23000 160.08882 0.62579    1
# 20353              CCCC#Cc1ccccc1O 2.54380 20.23000 160.08882 0.62579    1
# 22488             N#CC1C=CCCC(S)C1 2.16468 23.79000 153.06122 0.41824    2
# 1796        C#[N+]c1ccc(C(N)=S)cc1 1.91500 30.38000 163.03245 0.64093    1
#
#        hbd  active_probability
# 19481    1             0.11974
# 17108    1             0.03877
# 1793     1             0.00607
# 2620     1             0.00593
# 20353    1             0.00593
# 22488    1             0.00501
# 1796     1             0.00488
# 23067    1             0.00339
# 14662    1             0.00294
# 21876    1             0.00218
# 22634    1             0.00214
# 21742    1             0.00125
# 18094    1             0.00113
# 786      1             0.00103
# 14769    1             0.00100
# 5049     0             0.00066
# 20799    1             0.00060
# 17877    1             0.00057
# 1465     1             0.00054
# 22821    0             0.00053
# 15366    1             0.00043
# 17219    1             0.00040
# 10954    1             0.00030
# 9698     1             0.00024
# 3911     1             0.00022
# 15926    1             0.00018
# 2487     0             0.00015
# 21143    1             0.00014
# 19875    1             0.00010
# 8948     1             0.00010
# 17830    1             0.00009
# 12792    1             0.00008
# 16057    0             0.00007
# 10225    1             0.00005
# 5938     1             0.00005
# 13630    1             0.00005
# 16538    1             0.00005
# 21887    1             0.00005
# 16208    1             0.00003
# 11514    1             0.00003
# 7733     1             0.00001

# %%
data_com_tanimoto = calcula_tanimoto(smiles_target, data, 4)

# %%
data_com_tanimoto.sort_values(by="i_tanimoto", ascending=False)
# Out:
#                     Smiles                logp   tpsa          molwt  \
# 255    C=CC(C)(O)CCC=C(C)C  2.6698000000000013  20.23  154.135765196
# 4346     CC=CC(O)CCC=C(C)C  2.6698000000000013  20.23  154.135765196
# 3867     CCCC=CC1(O)C=CCC1   2.423800000000001  20.23  152.120115132
# 1613  CC(C)=CC(C)(C)CC(C)O   2.749700000000001  20.23   156.15141526
# 3273    CCC(C=C(C)C)CC(C)O  2.7497000000000016  20.23   156.15141526
# ...                    ...                 ...    ...            ...
# 2065   Cc1cc(C)c(O)c(C)c1C  2.6258800000000004  20.23  150.104465068
# 5173   Cc1cc(O)c(C)c(C)c1C  2.6258800000000004  20.23  150.104465068
# 443         Nc1ccccc1C(F)F  2.2064000000000004  26.02  143.054655664
# 44          Nc1ccccc1C(F)F  2.2064000000000004  26.02  143.054655664
# 4241     N=Nc1ccc2ccccc2c1   3.502270000000001  36.21  156.068748256
#
#                      qed hba hbd      active_probability  i_tanimoto
# 255   0.6171290071333285   1   1  2.8304322844892562e-05     1.00000
# 4346  0.6171290071333284   1   1    0.003230157451340934     0.65000
# 3867  0.6156613932781141   1   1   0.0018395761986526645     0.50000
# 1613  0.6228561127376835   1   1  4.2654030609296146e-05     0.50000
# 3273  0.6204402425865025   1   1   5.587940181050067e-05     0.50000
# ...                  ...  ..  ..                     ...         ...
# 2065  0.6024044487589301   1   1   8.776813731716311e-05     0.01000
# 5173  0.6024044487589301   1   1  0.00016905586909849154     0.01000
# 443   0.5990066223887058   1   1   6.228611297893845e-05     0.00000
# 44    0.5990066223887058   1   1   6.228611297893845e-05     0.00000
# 4241  0.6132715287270338   2   1   0.0001620675093553364     0.00000
#
# [24352 rows x 9 columns]

# %%
import sqlite3

# %%
con_ligs = sqlite3.connect("ligantes_linalool+.db")

# %%
data_com_tanimoto.to_sql("novos_ligantes", con_ligs, index=False, if_exists="replace")
